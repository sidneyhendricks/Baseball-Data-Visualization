# %%
import pandas as pd

# %%
#load datasets
teams1 = pd.read_csv('Teams.csv')
parks = pd.read_csv('Parks.csv')
parks1 = pd.read_csv('Parks1.csv')
teams1
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome    W    L  ...   DP  \
# 0       1871  NaN    BS1      BNA   NaN     3   31    NaN   20   10  ...   24
# 1       1871  NaN    CH1      CNA   NaN     2   28    NaN   19    9  ...   16
# 2       1871  NaN    CL1      CFC   NaN     8   29    NaN   10   19  ...   15
# 3       1871  NaN    FW1      KEK   NaN     7   19    NaN    7   12  ...    8
# 4       1871  NaN    NY2      NNA   NaN     5   33    NaN   16   17  ...   14
# ...      ...  ...    ...      ...   ...   ...  ...    ...  ...  ...  ...  ...
# 2980    2021   NL    SLN      STL     C     2  162   81.0   90   72  ...  137
# 2981    2021   AL    TBA      TBD     E     1  162   81.0  100   62  ...  130
# 2982    2021   AL    TEX      TEX     W     5  162   81.0   60  102  ...  146
# 2983    2021   AL    TOR      TOR     E     4  162   80.0   91   71  ...  122
# 2984    2021   NL    WAS      WSN     E     5  162   81.0   65   97  ...  116
#
# ...

# %%
#only select columns of interest
#park_state = parks[['park.name', 'state']].rename(columns = {'park.name': 'park'})

# %%
#ps = park_state.set_index('park')
#state_dict = ps['state'].to_dict()

# %%
#teams1['state'] = teams1['park'].map(state_dict)

# %%
#teams1

# %%
parks1[['NAME', 'STATE', 'Longitude', 'Latitude']]
# Out:
#                                     NAME STATE   Longitude   Latitude
# 0                         Riverside Park    NY  -73.745198  42.642295
# 1                          Columbia Park    PA  -78.411164  40.494582
# 2               Angel Stadium of Anaheim    CA -117.882685  33.800290
# 3                      Arlington Stadium    TX  -97.084778  32.755974
# 4                        Globe Life Park    TX  -97.082546  32.751164
# ..                                   ...   ...         ...        ...
# 250                         Bowman Field    PA  -77.047067  41.242347
# 251     West New York Field Club Grounds    NJ  -74.019648  40.772796
# 252   Agricultural County Fair Grounds I    MA  -71.814226  42.268844
# 253  Agricultural County Fair Grounds II    MA  -71.814226  42.268844
# 254       Worcester Driving Park Grounds    MA  -71.812404  42.268721
#
# [255 rows x 4 columns]

# %%
park_state = parks1[['NAME', 'STATE']].rename(columns = {'NAME': 'park'}).set_index('park')
park_lon = parks1[['NAME', 'Longitude']].rename(columns = {'NAME': 'park'}).set_index('park')
park_lat = parks1[['NAME', 'Latitude']].rename(columns = {'NAME': 'park'}).set_index('park')

# %%
state_dict = park_state['STATE'].to_dict()
lon_dict = park_lon['Longitude'].to_dict()
lat_dict = park_lat['Latitude'].to_dict()

# %%
teams1['state'] = teams1['park'].map(state_dict)
teams1['longitude'] = teams1['park'].map(lon_dict)
teams1['latitude'] = teams1['park'].map(lat_dict)

# %%
teams1.to_csv('../teams1.csv', index=False)
